# %%
import pandas as pd

# %%
df = pd.read_excel("./data/dancers.xlsx")
df
# Out:
#                  Timestamp                  Name:  \
# 0  2020-10-15 10:54:32.703               Addie Li
# 1  2020-10-15 12:55:25.841            Aditi Malay
# 2  2020-10-15 12:07:28.400    Amulya Vallabhaneni
# 3  2020-10-16 14:25:30.048          Ankit Chhajed
# 4  2020-10-16 01:07:39.207           Anusha Chegu
# 5  2020-10-15 12:01:18.065             Asha Patel
# 6  2020-10-15 11:31:12.457            Ashna Ahuja
# 7  2020-10-16 13:59:24.818         Ashwini Murthy
# 8  2020-10-15 11:12:33.398             Baaj Arora
# 9  2020-10-15 14:49:56.214  Bhavana Angalakudati
# 10 2020-10-15 15:09:51.131          Divya Srihari
# 11 2020-10-15 11:33:32.997      Gautami Kankipati
# 12 2020-10-15 11:35:23.673        Grihith Varaday
# 13 2020-10-15 11:28:48.962           Harsh Wadhwa
# 14 2020-10-15 10:51:51.127          Hiba Mohammad
# 15 2020-10-15 19:07:40.087           Iris Beckham
# 16 2020-10-15 10:50:11.594           Isabel Huesa
# 17 2020-10-15 19:44:17.220     Jaitsiri Ahluwalia
# ...

# %%
teams = pd.read_excel("./data/teams.xlsx")
teams
# Out:
#                 Timestamp    Team:  \
# 0 2020-10-16 09:26:56.610      STL
# 1 2020-10-16 13:51:14.637     Raas
# 2 2020-10-16 14:42:32.801  Chaahat
# 3 2020-10-16 15:57:16.528  Bhangra
# 4 2020-10-16 23:53:18.017    Garba
#
#    List girl dancers/singers in order of preference:  \
# 0  Rupa Ballamudi\nSandhya Thomas\nAshwini Murthy...
# 1  Neha Perumal\nAshwini Murthy\nAsha Patel\nIsab...
# 2  Prerana Acharayya\nJaitsiri Ahluwalia\nRuth Al...
# 3  Jaitsri Ahluwalia \nNeha Adhari\nIsabel Huesa\...
# 4  Aditi Malay\nRupa Ballamudi\nMaya Mehrotra\nKh...
#
#     List boy dancers/singers in order of preference:  \
# 0                                    Kayzad Bharucha
# 1  Amulya Vallabhaneni\nShikha Shah \nGautami Kan...
# 2      Kiran Mammen\nAnkit Chhajed \nGrihith Varaday
# 3  Baaj Arora\nOmer Kazmi\nHarsh Wadhwa\nTejas Se...
# 4                                                NaN
#
#    How many returners are on your team this year?  \
# ...

# %%
from program import Program
prog = Program()
prog.handle_students_file("./data/dancers.xlsx")

# %%
prog.handle_teams_file("./data/teams.xlsx")

# %%
prog.algo.teams["Chaahat - Females"].prefs
# Out:
# 'Prerana Acharayya\nJaitsiri Ahluwalia\nRuth Alemu\nAddie Li\nSapna Nakshatri \nAditi Malay\nIris Beckham\nNirali Somia\nShria Bucha\n'

# %%
prog.run_matching()
# Out:
# Addie Li added to team Chaahat - Females
# Aditi Malay not ranked by team Bhangra - Females
# Aditi Malay added to team Garba - Females
# Amulya Vallabhaneni not ranked by team Raas - Females
# Amulya Vallabhaneni added to team Raas - Males
# Ankit Chhajed added to team Chaahat - Males
# Anusha Chegu added to team STL - Females
# Asha Patel added to team Raas - Females
# Ashna Ahuja not ranked by team STL - Females
# Ashna Ahuja out of teams. Unassigned :(
# Ashwini Murthy not ranked by team Chaahat - Females
# Ashwini Murthy added to team Raas - Females
# Baaj Arora added to team Bhangra - Males
# Bhavana Angalakudati  not ranked by team Chaahat - Females
# Bhavana Angalakudati  not ranked by team Raas - Females
# Bhavana Angalakudati  not ranked by team Raas - Males
# Bhavana Angalakudati  out of teams. Unassigned :(
# Divya Srihari added to team Bhangra - Females
# Gautami Kankipati not ranked by team Raas - Females
# Gautami Kankipati added to team Raas - Males
# ...

# %%
prog.algo.teams["STL - Females"].roster

# %%
prog.algo.teams["STL - Males"].roster

# %%
prog.algo.teams["Raas - Females"].roster

# %%
prog.algo.teams["Raas - Males"].roster

# %%
prog.algo.teams["Chaahat - Females"].roster

# %%
prog.algo.teams["Chaahat - Males"].roster

# %%
prog.algo.teams["Bhangra - Females"].roster

# %%
prog.algo.teams["Bhangra - Males"].roster

# %%
prog.algo.teams["Garba - Females"].roster
